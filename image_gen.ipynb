              , 0.553, 0.5588, 0.571, 0.567, 0.5618, 0.5668, 0.5642, 0.5682, 0.5676, 0.5638, 0.5716, 0.5602, 0.5712
              , 0.5642, 0.5758, 0.564, 0.5758, 0.5676, 0.5812, 0.5718, 0.5782, 0.5644, 0.5762, 0.5706, 0.5682, 0.5738
              , 0.5778, 0.5734, 0.5694, 0.5666, 0.5644, 0.5758, 0.5658, 0.5662, 0.5698, 0.5804, 0.565, 0.5784, 0.578, 0.5654
            ]


#MOD graph
mod_array = []
for i in range(0,mod1_count - 1):
    mod_array.append(mod1_array[i])
"""harmonic_array = []
for i in range(0, mod1_count - 1):
    if i == 0:
        harmonic_array.append(1)
    else:
        harmonic_array.append((1/(i + 1)) + harmonic_array[i-1])"""

plt.title(f"Modulus Values of Permutations of Size {1} to {mod1_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod1_count), mod_array, label="Approximate Values")
#plt.scatter(range(1, mod1_count), harmonic_array, label="Harmonic Values")
plt.legend(loc="lower right")
plt.savefig("MOD1_standard.png")

#/n graph
"""
over_n_array = []
for i in range(0,mod1_count - 1):
    over_n_array.append(mod1_array[i] / (i + 1))

plt.title(f"Modulus / n Values of Permutations of Size {1} to {mod1_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod1_count), over_n_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("graph.png")
"""

#/sqrt(n) graph
"""
over_sqrtn_array = []
for i in range(0,mod1_count - 1):
    over_sqrtn_array.append(mod1_array[i] / math.sqrt(i + 1))

plt.title(f"Modulus / sqrt(n) Values of Permutations of Size {1} to {mod1_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod1_count), over_sqrtn_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("graph.png")
"""
"""
#/ln(mod) and ln(n) graph

log_mod_array = []
for i in range(0,mod1_count - 1):
    log_mod_array.append(math.log(mod1_array[i]))

log_array = []
for i in range(0,mod1_count - 1):
    log_array.append(math.log((i + 1)))  

small_log_array = []
for i in range(0,mod1_count - 1):
    small_log_array.append(math.log((i + 1)) / 3) 

plt.title(f"log of Modulus Values of Permutations of Size {1} to {mod1_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod1_count), log_mod_array, label="Approximate Values")
plt.scatter(range(1, mod1_count), log_array, label="ln(n) Values")
plt.scatter(range(1, mod1_count), small_log_array, label="1/3 * ln(n) Values")
plt.legend(loc="lower right")
plt.savefig("graph.png")
"""

#inverse MOD graph
"""
over_n_array = []
for i in range(0,mod1_count - 1):
    over_n_array.append(1 / mod1_array[i])

plt.title(f"Modulus^{-1} Values of Permutations of Size {1} to {mod1_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod1_count), over_n_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("graph.png")
"""
#longest MISS graph
"""
longest_miss = []
for i in range(0,longest_miss_array_count - 1):
    longest_miss.append(longest_miss_array[i])

log_array = []
for i in range(0,longest_miss_array_count - 1):
    log_array.append(2 * math.log((i + 1)))  

plt.title(f"Longest MISS of Permutations of Size {1} to {longest_miss_array_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Length of longest MISS")
plt.scatter(range(1, longest_miss_array_count), longest_miss, label="Approximate Values")
plt.scatter(range(1, longest_miss_array_count), log_array, label="2*ln(n) Values")
plt.legend(loc="lower right")
plt.savefig("longest_MISS.png")
"""
"""
#P(MC(pi+j) > MC(pi))
prob = []
for i in range(0,add_1_count - 1):
    prob.append(add_1_array[i])

plt.title(f"P(MC(pi+j) > MC(pi)) of Permutations of Size {1} to {longest_miss_array_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Probability")
plt.scatter(range(1, add_1_count), prob, label="Approximate Values")
plt.ylim(0, 1.1)
plt.legend(loc="lower right")
plt.savefig("P(MC(pi+j) > MC(pi)).png")
"""
"""
#MOD2 graph

mod_array = []
for i in range(0,mod2_count - 1):
    mod_array.append(mod2_array[i])

plt.title(f"Mod 2 Values of Permutations of Size {1} to {mod2_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod2_count), mod_array, label="Approximate Values")
plt.legend(loc="lower right")
plt.savefig("MOD2.png")

"""
"""
#/n graph

over_n_array = []
for i in range(0,mod2_count - 1):
    over_n_array.append(mod2_array[i] / (i + 1))

plt.title(f"Mod 2 / n Values of Permutations of Size {1} to {mod2_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod2_count), over_n_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("MOD2_over_n.png")

"""
"""
#/sqrt(n) graph

over_sqrtn_array = []
for i in range(0,mod2_count - 1):
    over_sqrtn_array.append(mod2_array[i] / math.sqrt(i + 1))

plt.title(f"Mod 2 / sqrt(n) Values of Permutations of Size {1} to {mod2_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod2_count), over_sqrtn_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("MOD2_over_sqrtn.png")

"""
"""
#/ln(mod) and ln(n) graph

log_mod_array = []
for i in range(0,mod2_count - 1):
    log_mod_array.append(math.log(mod2_array[i]))

log_array = []
for i in range(0,mod2_count - 1):
    log_array.append(math.log((i + 1))) 

small_log_array = []
for i in range(0,mod2_count - 1):
    small_log_array.append(math.log((i + 1)) / 7)  

plt.title(f"log of Mod 2 Values of Permutations of Size {1} to {mod2_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod2_count), log_mod_array, label="Approximate Values")
plt.scatter(range(1, mod2_count), log_array, label="ln(n) Values")
plt.scatter(range(1, mod2_count), small_log_array, label="1/7 * ln(n) Values")
plt.legend(loc="center right")
plt.savefig("ln(MOD2).png")
"""
"""
#inverse MOD graph

over_n_array = []
for i in range(0,mod2_count - 1):
    over_n_array.append(1 / mod2_array[i])

plt.title(f"Mod^{-1} 2 Values of Permutations of Size {1} to {mod2_count}")
plt.xlabel("Size of Permutation")
plt.ylabel("Value of Modulus")
plt.scatter(range(1, mod2_count), over_n_array, label="Approximate Values")
plt.legend(loc="upper right")
plt.savefig("inverse_MOD2.png")

"""
# Out:
# '\n#inverse MOD graph\n\nover_n_array = []\nfor i in range(0,mod2_count - 1):\n    over_n_array.append(1 / mod2_array[i])\n\nplt.title(f"Mod^{-1} 2 Values of Permutations of Size {1} to {mod2_count}")\nplt.xlabel("Size of Permutation")\nplt.ylabel("Value of Modulus")\nplt.scatter(range(1, mod2_count), over_n_array, label="Approximate Values")\nplt.legend(loc="upper right")\nplt.savefig("inverse_MOD2.png")\n\n'
